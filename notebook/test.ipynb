# %%
import  pandas as pd

# %%
gedi = pd.read_csv("../data/CSV/gedi.csv")
sentinel_1 = pd.read_csv("../data/CSV/sentinel_1.csv")
sentinel_2 = pd.read_csv("../data/CSV/sentinel_2.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 gedi = pd.read_csv("../data/CSV/gedi.csv")
#       2 sentinel_1 = pd.read_csv("../data/CSV/sentinel_1.csv")
#       3 sentinel_2 = pd.read_csv("../data/CSV/sentinel_2.csv")
#
# ...

# %%
gedi
# Out:
#                 x          y  spatial_ref  rh98  rh100        time
# 0       43.133013  14.736638            0   NaN    NaN  2019-04-01
# 1       43.133013  14.736548            0   NaN    NaN  2019-04-01
# 2       43.133013  14.736458            0   NaN    NaN  2019-04-01
# 3       43.133013  14.736368            0   NaN    NaN  2019-04-01
# 4       43.133013  14.736278            0   NaN    NaN  2019-04-01
# ...           ...        ...          ...   ...    ...         ...
# 617710  43.156728  14.713820            0   NaN    NaN  2019-12-01
# 617711  43.156728  14.713731            0   NaN    NaN  2019-12-01
# 617712  43.156728  14.713641            0   NaN    NaN  2019-12-01
# 617713  43.156728  14.713551            0   NaN    NaN  2019-12-01
# 617714  43.156728  14.713461            0   NaN    NaN  2019-12-01
#
# [617715 rows x 6 columns]

# %%
merged_data_1 = pd.merge(sentinel_2, sentinel_1,on=['time', 'x', 'y'], how='outer')

# %%
gedi['time'] = pd.to_datetime(gedi['time'])

# Extraire uniquement la date
gedi['time1'] =gedi['time'].dt.date

# %%
merged_data = pd.merge(merged_data_1, gedi,on=['time', 'x', 'y'], how='outer')
merged_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 merged_data = pd.merge(merged_data_1, gedi,on=['time', 'x', 'y'], how='outer')
#       2 merged_data
#
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/pandas/core/reshape/merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
# ...

# %%
merged_data = merged_data.dropna(subset=['rh98'], axis=0)

merged_data
# Out:
#               time          x          y  spatial_ref_x       B1      B2  \
# 69517   2019-05-01  43.133282  14.722893              0  0.11810  0.1436
# 69518   2019-05-01  43.133282  14.722983              0  0.11810  0.1438
# 69776   2019-05-01  43.133372  14.722893              0  0.11810  0.1452
# 69777   2019-05-01  43.133372  14.722983              0  0.11810  0.1437
# 70035   2019-05-01  43.133462  14.722893              0  0.11700  0.1430
# ...            ...        ...        ...            ...      ...     ...
# 480130  2019-10-01  43.156638  14.731697              0  0.09555  0.1211
# 480131  2019-10-01  43.156638  14.731787              0  0.09555  0.1193
# 480383  2019-10-01  43.156728  14.731158              0  0.09455  0.1244
# 480384  2019-10-01  43.156728  14.731248              0  0.09455  0.1236
# 480385  2019-10-01  43.156728  14.731338              0  0.09555  0.1284
#
#             B3      B4       B5       B6  ...  QA10  QA20  QA60  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/gedi_output.nc/gedi.csv')

# %%
df.isnull().sum()
# Out:
# x              0
# y              0
# spatial_ref    0
# rh98           0
# rh100          0
# time           0
# dtype: int64

# %%
df = pd.read_csv('/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/test/gedi_2019.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df = pd.read_csv('/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/test/gedi_2019.csv')
#
# ...

# %%
len(df.shape)
# Out:
# 2

# %%
df1 =pd.read_csv('/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/test/sentinel_1_2019.csv')
df1.
# Out:
# (617715, 7)

# %%
df2 = pd.read_csv("/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/test/test.csv")
#df3 = df2.dropna(subset=["rh98"], axis=1)

# %%
df2.
# Out:
#         Unnamed: 0                 time          x          y  spatial_ref  \
# 0                0  2019-05-01 08:00:00  43.133013  14.736638            0
# 1                1  2019-05-01 08:00:00  43.133013  14.736548            0
# 2                2  2019-05-01 08:00:00  43.133013  14.736458            0
# 3                3  2019-05-01 08:00:00  43.133013  14.736368            0
# 4                4  2019-05-01 08:00:00  43.133013  14.736278            0
# ...            ...                  ...        ...        ...          ...
# 137265       68630  2019-10-01 08:00:00  43.156728  14.713820            0
# 137266       68631  2019-10-01 08:00:00  43.156728  14.713731            0
# 137267       68632  2019-10-01 08:00:00  43.156728  14.713641            0
# 137268       68633  2019-10-01 08:00:00  43.156728  14.713551            0
# 137269       68634  2019-10-01 08:00:00  43.156728  14.713461            0
#
# ...

# %%
df2['rh100'].unique()
# Out:
# array([        nan,  3.18000007,  3.4000001 ,  3.22000003,  3.32999992,
#         3.0999999 ,  3.36999989,  3.25      ,  2.92000008,  3.1400001 ,
#         2.95000005,  3.28999996,  3.44000006,  3.02999997,  3.05999994,
#         3.70000005,  3.50999999,  4.1500001 ,  5.69000006,  4.07999992,
#         3.51999998,  2.99000001,  2.88000011,  3.80999994,  4.53000021,
#         3.8499999 , 15.5       ,  3.8900001 ,  3.06999993,  4.19000006,
#         5.94999981,  3.58999991,  4.        ,  3.48000002,  4.40999985,
#         3.93000007,  2.76999998,  3.66000009,  2.83999991,  3.63000011,
#         3.74000001,  4.48000002,  3.92000008,  4.67000008,  4.78000021,
#         4.36999989,  3.76999998,  4.17999983,  3.17000008,  4.21999979,
#         3.88000011,  3.54999995,  4.75      ,  4.03000021,  4.63000011,
#         4.86000013,  3.21000004,  3.47000003,  4.51999998,  3.31999993,
#         7.36000013,  5.07999992,  3.3599999 ,  3.61999989,  4.44999981,
# ...

# %%
import pandas as pd 

df = pd.read_csv("/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/src/Combined_Data.csv")

# %%
# Transformer 'Region_1' à 'Region_400' en 'Region_401' à 'Region_800'
df['polygon'] = df['polygon'].str.replace('polygon_', '').astype(int) + 400
df['polygon'] = 'polygon_' + df['polygon'].astype(str) # Affiche les premières lignes pour vérifier le renommage

# %%
df.to_csv("test.csv", index=False)

# %%
df1 = pd.read_csv("/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/data/CSV/Combined_Data.csv")
df1.shape
# Out:
# (214747, 44)

# %%
df2 = pd.read_csv("/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/notebook/test.csv")
df2.shape
# Out:
# (271081, 44)

# %%
concat = pd.concat([df1, df2])

# %%
concat.to_csv("data_dframe_gedi_s1_and_s2.csv", index=False)

# %%
import pandas as pd

# %%
cv =pd.read_csv("/Users/clementkm/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/data/CSV/data_dframe_gedi_s1_and_s2.csv")
cv.shape
# Out:
# (485828, 44)

# %%
cv
# Out:
#                        time          x          y  spatial_ref       rh98  \
# 0       2020-05-01 08:00:00  45.691055  34.259454            0   3.880000
# 1       2020-05-01 08:00:00  45.691055  34.259364            0   3.880000
# 2       2020-05-01 08:00:00  45.691415  34.259724            0  18.370001
# 3       2020-05-01 08:00:00  45.691415  34.259634            0  18.370001
# 4       2020-05-01 08:00:00  45.691415  34.259544            0  18.370001
# ...                     ...        ...        ...          ...        ...
# 485823  2020-10-01 08:00:00   9.764193  35.195589            0   2.390000
# 485824  2020-10-01 08:00:00   9.764283  35.213555            0   2.470000
# 485825  2020-10-01 08:00:00   9.764283  35.213465            0   2.470000
# 485826  2020-10-01 08:00:00   9.764283  35.195499            0   2.540000
# 485827  2020-10-01 08:00:00   9.764283  35.195409            0   2.540000
#
#         rh100      time.1        x.1        y.1  spatial_ref.1  ...   TCI_B  \
# ...

# %%
cv.isnull().sum()
# Out:
# time                        0
# x                           0
# y                           0
# spatial_ref                 0
# rh98                        0
# rh100                       0
# time.1                      0
# x.1                         0
# y.1                         0
# spatial_ref.1               0
# VV                        142
# VH                        142
# angle                       0
# time.2                      0
# x.2                         0
# y.2                         0
# spatial_ref.2               0
# B1                        898
# B2                        815
# B3                        820
# B4                        815
# B5                        815
# B6                        821
# B7                        821
# B8                        815
# B8A                       823
# B9                        812
# B11                       815
# B12                       815
# AOT                       815
# WVP                       815
# ...

# %%
cv.columns
# Out:
# Index(['time', 'x', 'y', 'spatial_ref', 'rh98', 'rh100', 'time.1', 'x.1',
#        'y.1', 'spatial_ref.1', 'VV', 'VH', 'angle', 'time.2', 'x.2', 'y.2',
#        'spatial_ref.2', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A',
#        'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B',
#        'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE',
#        'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE', 'polygon'],
#       dtype='object')

# %%
import ee
cloud_project = 'ee-ckafwimbi'

try:
        ee.Initialize(project=cloud_project)
except:
        ee.Authenticate()
        ee.Initialize(project=cloud_project)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/ee/data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# ...

# %%
cv.clip(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cv.clip(2)
#
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/pandas/core/generic.py:8745, in NDFrame.clip(self, lower, upper, axis, inplace, **kwargs)
#    8743 # fast-path for scalars
#    8744 if (lower is None or is_number(lower)) and (upper is None or is_number(upper)):
# -> 8745     return self._clip_with_scalar(lower, upper, inplace=inplace)
#    8747 result = self
#    8748 if lower is not None:
#
# File ~/Documents/School/TOLBI STAGE /PROJECT/Data_Collection_and_Processing/env/lib/python3.9/site-packages/pandas/core/generic.py:8547, in NDFrame._clip_with_scalar(self, lower, upper, inplace)
#    8544 mask = self.isna()
#    8546 if lower is not None:
# -> 8547     cond = mask | (self >= lower)
#    8548     result = result.where(
# ...

# %%
import geopandas as gpd

# %%
data = gpd.read_file('/Users/clementkm/Documents/JOBS/TOLBI/data/data_collection_mission_arachide_casamance_2024.geojson')

# %%
data = data.rename(columns={"Veuillez choisir la culture trouvée": "Renseigner la culture"})

# %%
data['Zone'] = "Casamance"

# %%
data.columns
# Out:
# Index(['fid', 'Nom de l'enqueteur', 'Prenom de l'enqueteur',
#        'Telephone de l'enqueteur', 'Renseigner la culture', '_id_record',
#        'Si autre, entrez le nom de la culture', 'Surface en ha', 'layer',
#        'path', 'geometry', 'Zone'],
#       dtype='object')

# %%
data.to_file("../data/data_collection_mission_arachide_casamance_2024", driver="GeoJSON")

# %%
data = data.drop(['layer', 'path'], axis=1)

# %%
data.head()
# Out:
#    fid Nom de l'enqueteur Prenom de l'enqueteur Telephone de l'enqueteur  \
# 0    1            Ndiaye             Ousseynou                 774959377
# 1    2            SABALY                Issaga                 772495133
# 2    3            Ndiaye             Ousseynou                 774959377
# 3    4            Ndiaye             Ousseynou                 774959377
# 4    5            Ndiaye             Ousseynou                 774959377
#
#   Renseigner la culture  _id_record Si autre, entrez le nom de la culture  \
# 0              arachide         362                                  None
# 1                 niébé         377                                  None
# 2              arachide         354                                  None
# 3              arachide         355                                  None
# 4              arachide         356                                  None
#
#    Surface en ha                                           geometry       Zone
# ...

# %%
data["Renseigner la culture"] = data["Renseigner la culture"].str.lower()
new_data = data

# %%
new_data["Renseigner la culture"].value_counts()
# Out:
# Renseigner la culture
# arachide                            1693
# autre                                225
# maïs                                 126
# mil                                   75
# herbres                               73
# arachide+niébé                        57
# niébé                                 40
# riz                                   19
# sorgho                                17
# oseille                               13
# arachide+mil                          12
# arachide+oseille                      11
# mil, arachide                          8
# arachide, oseille                      5
# arachide+maïs                          4
# arachide, autre                        3
# arachide, mil                          3
# arachide, riz                          2
# arachide+oseille, arachide+niébé       1
# niébé, autre                           1
# mil, maïs                              1
# sorgho, maïs                           1
# ...

# %%
new_data.to_file('../data/data_collection_mission_arachide_casamance_2024.geojson', driver="GeoJSON")

# %%
data_collection_kaolack = gpd.read_file('../data/INTERNE/map (2).geojson')

# %%
data_collection_kaolack['Zone']="Kaolack"

# %%
data_collection_kaolack["Renseigner la culture"].value_counts()
# Out:
# Renseigner la culture
# arachide          78
# mil               24
# arachide+mil      12
# maïs               8
# arachide+niébé     7
# niébé              3
# Name: count, dtype: int64

# %%
data_collection_kaolack.to_file('../data/INTERNE/data_collection_mission_arachide_kaolack_.geojson',driver="GeoJSON")

# %%
import pandas as pd

# %%
casamance = gpd.read_file('../data/INTERNE/data_collection_mission_arachide_casamance_2024.geojson')
kaolack = gpd.read_file('../data/INTERNE/data_collection_mission_arachide_kaolack_.geojson')

kaolack.columns
# Out:
# Index(['avatar', 'Nom de l'enqueteur', 'Prenom de l'enqueteur',
#        'Renseigner la culture', 'Telephone de l'enqueteur',
#        'Décricez l'état de santé des cultures dans la zone-',
#        'Donner une approximation du pourcentage d"herbes dans la zone',
#        'Quelle est la phénologie actuelle de la culture dans la zone?',
#        'Veuillez renseigner la culture présente (si c'est mixte renseigner les cultures présente dans la zone)-',
#        '_id_record', 'Zone', 'geometry'],
#       dtype='object')

# %%
casamance.columns
# Out:
# Index(['fid', 'Nom de l'enqueteur', 'Prenom de l'enqueteur',
#        'Telephone de l'enqueteur', 'Renseigner la culture', '_id_record',
#        'Si autre, entrez le nom de la culture', 'Surface en ha', 'Zone',
#        'geometry'],
#       dtype='object')

# %%
colonnes_communes = ["Nom de l'enqueteur", "Prenom de l'enqueteur",
       "Renseigner la culture", "Telephone de l'enqueteur","_id_record", "Zone", "geometry"]

# %%
combined_gdf = casamance.merge(kaolack, on=colonnes_communes, how='inner')

# %%
combined_gdf
# Out:
# Empty GeoDataFrame
# Columns: [fid, Nom de l'enqueteur, Prenom de l'enqueteur, Telephone de l'enqueteur, Renseigner la culture, _id_record, Si autre, entrez le nom de la culture, Surface en ha, Zone, geometry, avatar, Décricez l'état de santé des cultures dans la zone-, Donner une approximation du pourcentage d"herbes dans la zone, Quelle est la phénologie actuelle de la culture dans la zone?, Veuillez renseigner la culture présente (si c'est mixte renseigner les cultures présente dans la zone)-]
# Index: []

# %%
combined = pd.concat([casamance,kaolack], ignore_index=True)
combined.dtypes
# Out:
# fid                                                                                                         float64
# Nom de l'enqueteur                                                                                           object
# Prenom de l'enqueteur                                                                                        object
# Telephone de l'enqueteur                                                                                     object
# Renseigner la culture                                                                                        object
# _id_record                                                                                                    int32
# Si autre, entrez le nom de la culture                                                                        object
# Surface en ha                                                                                               float64
# ...

# %%
combined.to_file("../data/INTERNE/data_collection_mission_arachide_2024.geojson", driver="GeoJSON")

# %%
# Convertir les colonnes entières en int16
casamance['fid'] = casamance['fid'].astype('int16')
casamance['_id_record'] = casamance['_id_record'].astype('int16')



# Vérifier les types de données après la conversion
print(casamance.dtypes)
# Out:
# fid                                         int16
# Nom de l'enqueteur                         object
# Prenom de l'enqueteur                      object
# Telephone de l'enqueteur                   object
# Renseigner la culture                      object
# _id_record                                  int16
# Si autre, entrez le nom de la culture      object
# Surface en ha                             float64
# Zone                                       object
# geometry                                 geometry
# dtype: object

# %%
rice_datase_1 = gpd.read_file('../../DATA GEOJSON/roi_st_louis.geojson')
rice_dataset_2 = gpd.read_file('../../DATA GEOJSON/rice_anambe.geojson')

dataset_rice = pd.concat([rice_datase_1 , rice_dataset_2])
dataset_rice["Renseigner la culture"] = "riz"

dataset_rice["_id_record"] = pd.RangeIndex(start=5300, stop=5300 + len(dataset_rice), step=1)
dataset_rice
# Out:
#     id                                           geometry  \
# 0    0  POLYGON ((-16.26345 16.51086, -16.26285 16.511...
# 1    1  POLYGON ((-16.26274 16.51123, -16.26225 16.511...
# 2    2  POLYGON ((-16.26254 16.51083, -16.26205 16.511...
# 3    3  POLYGON ((-16.26321 16.50828, -16.26274 16.508...
# 4    4  POLYGON ((-16.27291 16.48602, -16.2726 16.4861...
# ..  ..                                                ...
# 57  57  POLYGON ((-14.10851 12.98454, -14.10757 12.984...
# 58  58  POLYGON ((-14.11904 12.93898, -14.11819 12.939...
# 59  59  POLYGON ((-14.11862 12.93784, -14.11784 12.937...
# 60  60  POLYGON ((-14.11506 12.93962, -14.11434 12.939...
# 61  61  POLYGON ((-14.11346 12.93739, -14.11278 12.937...
#
#    Renseigner la culture  _id_record
# 0                    riz        5300
# 1                    riz        5301
# 2                    riz        5302
# 3                    riz        5303
# 4                    riz        5304
# ..                   ...         ...
# ...

# %%
dataset_rice.to_file("../data/INTERNE/data_collection_mission_arachide_2024_(riz).geojson", driver="GeoJSON")

dataset_rice
